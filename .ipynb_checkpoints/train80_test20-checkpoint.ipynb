# %%
import numpy
from sklearn.metrics import r2_score
numpy.random.seed(2)

x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

mymodel = numpy.poly1d(numpy.polyfit(train_x, train_y, 4))

myline = numpy.linspace(0, 6, 100)

plt.scatter(train_x, train_y,c=train_x, s=np.abs(train_y))
plt.plot(myline, mymodel(myline))
plt.show()

r2 = r2_score(test_y, mymodel(test_x))

# %%
#prediction of how much the customer would spend if he/she spends 5 minutes in the shop.
print("Customer would spend $"+str(mymodel(5)))
# Out:
# Customer would spend $22.879625918121064
